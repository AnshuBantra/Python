# %%
import pandas as pd

# %%
path = r'C:\Users\1270816\Documents\Anshu\GA\Python\Modelling\bank.csv'

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\1270816\\Documents\\Anshu\\Python\\Intro to Python'

# %%
os.chdir(r'C:\Users\1270816\Documents\Anshu\GA\Python\Modelling')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\1270816\\Documents\\Anshu\\GA\\Python\\Modelling'

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    age        job  marital    education  default  housing  loan    contact  \
# 0   56  housemaid  married     basic.4y      0.0      0.0   0.0  telephone
# 1   57   services  married  high.school      NaN      0.0   0.0  telephone
# 2   37   services  married  high.school      0.0      1.0   0.0  telephone
# 3   40     admin.  married     basic.6y      0.0      0.0   0.0  telephone
# 4   56   services  married  high.school      0.0      0.0   1.0  telephone
#
#   month day_of_week  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon         1    999         0  nonexistent           1.1
# 1   may         mon         1    999         0  nonexistent           1.1
# 2   may         mon         1    999         0  nonexistent           1.1
# 3   may         mon         1    999         0  nonexistent           1.1
# 4   may         mon         1    999         0  nonexistent           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# ...

# %%
df.drop(['default', 'housing', 'loan'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    age        job  marital    education    contact month day_of_week  \
# 0   56  housemaid  married     basic.4y  telephone   may         mon
# 1   57   services  married  high.school  telephone   may         mon
# 2   37   services  married  high.school  telephone   may         mon
# 3   40     admin.  married     basic.6y  telephone   may         mon
# 4   56   services  married  high.school  telephone   may         mon
#
#    campaign  pdays  previous     poutcome  emp.var.rate  cons.price.idx  \
# 0         1    999         0  nonexistent           1.1          93.994
# 1         1    999         0  nonexistent           1.1          93.994
# 2         1    999         0  nonexistent           1.1          93.994
# 3         1    999         0  nonexistent           1.1          93.994
# 4         1    999         0  nonexistent           1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed  y
# 0          -36.4      4.857       5191.0  0
# ...

# %%
df.to_csv(r'C:\Users\1270816\Documents\Anshu\GA\Python\Modelling\bank_1.csv')

# %%
df.to_excel
